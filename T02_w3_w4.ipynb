# %% [markdown]
# # Задания
#
# Выполните задания

# %% [markdown]
# ## 1.3. Операторы сравнения. Логические операторы. Инструкция ветвления if...else
#
# 1. Определить время года по номеру месяца.
# _______________________________________________________________________
# month = int(input("Введите номер месяца (от 1 до 12): "))
#
#
# if 1 <= month <= 12:
#     if 3 <= month <= 5:
#         season = "весна"
#     elif 6 <= month <= 8:
#         season = "лето"
#     elif 9 <= month <= 11:
#         season = "осень"
#     else:
#         season = "зима"
#
#     print(f"Время года для месяца {month} - это {season}.")
# else:
#     print("Некорректный номер месяца. Введите число от 1 до 12.")
#     ___________________________________________________________________
# 2. Определить минимальное значение среди чисел $a, b, c, d$ (не использовать стандартные функции max и min).
# ______________________________________________________________________________________________________________
# a = float(input("Введите число a: "))
# b = float(input("Введите число b: "))
# c = float(input("Введите число c: "))
# d = float(input("Введите число d: "))
#
# # Инициализация переменной для минимального значения
# min_value = a
#
# # Проверка и обновление минимального значения
# if b < min_value:
#     min_value = b
# if c < min_value:
#     min_value = c
# if d < min_value:
#     min_value = d
#
# # Вывод результата
# print("Минимальное значение среди чисел {} {} {} {} - это: {}".format(a, b, c, d, min_value))
# _____________________________________________________________________________________________________________
# 3. Напишите программу, которая переводит оценку из 100-балльной системы в пятибалльную по правилам, принятым в университете.
# _____________________________________________________________________________________________________________
# # Ввод оценки из 100-балльной системы
# score = int(input("Введите оценку (от 0 до 100): "))
#
# # Перевод в пятибалльную систему
# if 90 <= score <= 100:
#     grade = 5
# elif 75 <= score <= 89:
#     grade = 4
# elif 50 <= score <= 74:
#     grade = 3
# elif 25 <= score <= 49:
#     grade = 2
# elif 0 <= score <= 24:
#     grade = 1
# else:
#     print("Некорректная оценка. Введите число от 0 до 100.")
#     exit()
#
# # Вывод результата
# print(f"Оценка в пятибалльной системе: {grade}")
# ______________________________________________________________________________________________________________
# 4. Вычислить значение $F: F=1$, если цифра $7$ входит в запись заданного трехзначного числа, и $0$ – в противном случае.
# ______________________________________________________________________________________________________________
# # Ввод трехзначного числа
# number = int(input("Введите трехзначное число: "))
#
# # Проверка наличия цифры 7 в числе
# if '7' in str(number):
#     F = 1
# else:
#     F = 0
#
# # Вывод результата
# print("Значение F: {}".format(F))
# ______________________________________________________________________________________________________________
# 5. Даны два отрезка $[a;b]$ и $[c;d]$. Найдите их пересечение. Если отрезки не пересекаются, то выдайте сообщение.
# ______________________________________________________________________________________________________________
# # Ввод границ отрезков
# a = float(input("Введите начало первого отрезка (a): "))
# b = float(input("Введите конец первого отрезка (b): "))
# c = float(input("Введите начало второго отрезка (c): "))
# d = float(input("Введите конец второго отрезка (d): "))
#
# # Проверка наличия пересечения
# if max(a, c) <= min(b, d):
#     intersection_start = max(a, c)
#     intersection_end = min(b, d)
#     print("Отрезки пересекаются. Их пересечение: [{}, {}]".format(intersection_start, intersection_end))
# else:
#     print("Отрезки не пересекаются.")
# ______________________________________________________________________________________________________________
# 6. По номеру года определите, является ли данный год високосным. (год является високосным, если его номер кратен 4, но не кратен 100, а также если он кратен 400).
# ______________________________________________________________________________________________________________
# # Ввод номера года
# year = int(input("Введите год: "))
#
# # Проверка на високосность
# if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#     print(f"{year} год является високосным.")
# else:
#     print(f"{year} год не является високосным.")
#
# 7. Для отрезков длины a, b, c определить, можно ли из них составить треугольник и является ли этот треугольник прямоугольным.
# ______________________________________________________________________________________________________________
# # Ввод длин отрезков
# a = float(input("Введите длину отрезка a: "))
# b = float(input("Введите длину отрезка b: "))
# c = float(input("Введите длину отрезка c: "))
#
# # Проверка условий треугольника
# if a + b > c and a + c > b and b + c > a:
#     print("Из этих отрезков можно составить треугольник.")
#
#     # Проверка условий прямоугольного треугольника
#     if a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
#         print("Треугольник является прямоугольным.")
#     else:
#         print("Треугольник не является прямоугольным.")
# else:
#     print("Из этих отрезков нельзя составить треугольник.")
# ________________________________________________________________________________________________________________
# 8. Напишите программу для решения уравнения
# $$ ax^2+bx+c=0 $$
# Коэффициенты $a, b, c$ могут быть любыми числами.
# ________________________________________________________________________________________________________________
# import math
#
# # Ввод коэффициентов уравнения
# a = float(input("Введите коэффициент a: "))
# b = float(input("Введите коэффициент b: "))
# c = float(input("Введите коэффициент c: "))
#
# # Вычисление дискриминанта
# D = b**2 - 4*a*c
#
# # Решение уравнения
# if D > 0:
#     x1 = (-b + math.sqrt(D)) / (2*a)
#     x2 = (-b - math.sqrt(D)) / (2*a)
#     print("Уравнение имеет два корня: x1 = {:.2f}, x2 = {:.2f}".format(x1, x2))
# elif D == 0:
#     x = -b / (2*a)
#     print("Уравнение имеет один корень: x = {:.2f}".format(x))
# else:
#     print("Уравнение не имеет вещественных корней.")
# ________________________________________________________________________________________________________________
#
# 9. Вводится целое число. Выведите его на экран и допишите к нему слова «рубль», «рубля» или «рублей» в зависимости от значения. Алгоритм:
# - исключение: если число оканчивается на 11, 12, 13 или 14, добавляем слово «рублей»;
# - если число оканчивается на 1, добавляем слово «рубль»;
# - если число оканчивается на 2, 3 или 4, добавляем слово «рубля»;
# - если число оканчивается на цифры 5, 6, 7, 8, 9 или 0, добавляем слово «рублей».
# ________________________________________________________________________________________________________________
# # Ввод целого числа
# amount = int(input("Введите целое число: "))
#
# # Определение последней цифры числа
# last_digit = abs(amount) % 10
#
# # Определение и вывод результата
# if 10 < abs(amount) % 100 < 15:
#     print(f"{amount} рублей")
# elif last_digit == 1:
#     print(f"{amount} рубль")
# elif 2 <= last_digit <= 4:
#     print(f"{amount} рубля")
# else:
#     print(f"{amount} рублей")
# ________________________________________________________________________________________________________________
#
#
# 10. Пользователь поочередно вводит координаты точки в декартовой системе координат. Определить, какой четверти принадлежит данная точка или на какой оси она находится. Расположение точки вывести на экран. Найти произведение номера четверти на расстояние от этой точки до начала координат и вывести его на экран. Если точка лежит на оси, считать, что номер четверти равен 0.
# ________________________________________________________________________________________________________________
# # Ввод координат точки
# x = float(input("Введите координату x: "))
# y = float(input("Введите координату y: "))
#
# # Определение четверти
# if x > 0 and y > 0:
#     quadrant = 1
# elif x < 0 and y > 0:
#     quadrant = 2
# elif x < 0 and y < 0:
#     quadrant = 3
# elif x > 0 and y < 0:
#     quadrant = 4
# else:
#     quadrant = 0
#
# # Вывод расположения точки
# if quadrant == 0:
#     print(f"Точка лежит на координатной оси.")
# else:
#     print(f"Точка принадлежит {quadrant}-й четверти.")
#
# # Вычисление расстояния от начала координат
# distance = (x**2 + y**2)**0.5
#
# # Вычисление произведения номера четверти на расстояние
# product = quadrant * distance
#
# # Вывод результата
# print(f"Произведение номера четверти на расстояние от начала координат: {product}")
#
# ________________________________________________________________________________________________________________
# 11. Выведите значение заданного целого числа от 0 до 999 прописью. Например, «сто девяносто один» для числа 191, «одиннадцать» для числа 11.
# ________________________________________________________________________________________________________________
# def number_to_words(number):
#     units = ["", "один", "два", "три", "четыре", "пять", "шесть", "семь", "восемь", "девять"]
#     teens = ["", "одиннадцать", "двенадцать", "тринадцать", "четырнадцать", "пятнадцать", "шестнадцать", "семнадцать", "восемнадцать", "девятнадцать"]
#     tens = ["", "десять", "двадцать", "тридцать", "сорок", "пятьдесят", "шестьдесят", "семьдесят", "восемьдесят", "девяносто"]
#     hundreds = ["", "сто", "двести", "триста", "четыреста", "пятьсот", "шестьсот", "семьсот", "восемьсот", "девятьсот"]
#
#     if 0 <= number <= 999:
#         # Получение единиц, десятков и сотен
#         unit = number % 10
#         ten = (number % 100) // 10
#         hundred = number // 100
#
#         # Обработка чисел от 11 до 19
#         if ten == 1 and unit > 0:
#             result = hundreds[hundred] + " " + teens[unit]
#         else:
#             result = hundreds[hundred] + " " + tens[ten] + " " + units[unit]
#
#         return result.strip()
#
#     else:
#         return "Число должно быть от 0 до 999"
#
#
# # Ввод числа
# number = int(input("Введите число от 0 до 999: "))
#
# # Получение словесного представления
# words_representation = number_to_words(number)
#
# # Вывод результата
# print(words_representation)
# ________________________________________________________________________________________________________________
# 12. Вычислите значение выражения, которое состоит из целых чисел и знаков «+» и «-». Выражение вводится как символьная строка.
# ________________________________________________________________________________________________________________
# # Ввод выражения
# expression = input("Введите выражение: ")
#
# try:
#     # Вычисление значения выражения
#     result = eval(expression)
#
#     # Вывод результата
#     print("Результат выражения:", result)
#
# except (SyntaxError, NameError):
#     print("Некорректное выражение. Пожалуйста, введите корректное математическое выражение.")
# ________________________________________________________________________________________________________________
# 13. Пользователь поочередно вводит 2 строки. Определите, какая строка длиннее и на сколько символов, а какая строка стоит раньше в лексикографическом порядке. Собрать результирующую строку, которая бы содержала 1 и 2 строки, разделенные переносом строки.
# ________________________________________________________________________________________________________________
# # Ввод строк от пользователя
# string1 = input("Введите первую строку: ")
# string2 = input("Введите вторую строку: ")
#
# # Определение длины строк
# length1 = len(string1)
# length2 = len(string2)
#
# # Определение, какая строка длиннее и на сколько символов
# if length1 > length2:
#     longer_string = string1
#     difference_length = length1 - length2
# elif length2 > length1:
#     longer_string = string2
#     difference_length = length2 - length1
# else:
#     longer_string = None
#     difference_length = 0
#
# # Определение, какая строка идет раньше в лексикографическом порядке
# lexicographic_order = None
# if string1 < string2:
#     lexicographic_order = string1
# elif string2 < string1:
#     lexicographic_order = string2
#
# # Сбор результирующей строки
# result_string = f"Длина строки 1: {length1}, Длина строки 2: {length2}\n"
# if longer_string:
#     result_string += f"Строка {longer_string} длиннее на {difference_length} символов.\n"
# else:
#     result_string += "Строки имеют одинаковую длину.\n"
#
# if lexicographic_order:
#     result_string += f"Строка '{lexicographic_order}' идет раньше в лексикографическом порядке."
# else:
#     result_string += "Строки равны в лексикографическом порядке."
#
# # Вывод результата
# print(result_string)
# ________________________________________________________________________________________________________________
# 14. Реализовать калькулятор, который принимает от пользователя через пробел строку следующего вида: «a op b», где a и b – некоторые числа, а ‘op’ определяет оператор и может принимать значения $«+,-,*,/,**,%»$. В зависимости от оператора с помощью форматирования строк вывести результат в виде: «a + b = 3 + 2 = 5», где была получена строка «3 + 2». Для операций возведения в степень и деления по модулю использовать вместо знака оператора соответствующие выражения. Например, для строки «2 ** 3» должно быть выведено «a в степени b = 2 в степени 3 = 8».
# ________________________________________________________________________________________________________________
# # Ввод строки от пользователя
# input_string = input("Введите выражение (в формате 'a op b'): ")
#
# # Разбивка введенной строки на операнды и оператор
# operands, operator = input_string.split()[::2]
# a, b = map(float, operands)
#
# # Вычисление результата в зависимости от оператора
# if operator == '+':
#     result = a + b
#     operator_str = "сумма"
# elif operator == '-':
#     result = a - b
#     operator_str = "разность"
# elif operator == '*':
#     result = a * b
#     operator_str = "произведение"
# elif operator == '/':
#     result = a / b
#     operator_str = "частное"
# elif operator == '**':
#     result = a ** b
#     operator_str = "в степени"
# elif operator == '%':
#     result = a % b
#     operator_str = "остаток от деления"
# else:
#     print("Некорректный оператор. Поддерживаются операторы: +, -, *, /, **, %")
#     exit()
#
# # Форматирование строки с результатом
# output_string = f"{a} {operator} {b} = {a} {operator_str} {b} = {result}"
#
# # Вывод результата
# print(output_string)
# ________________________________________________________________________________________________________________
# 15. Напишите программу, которая в зависимости от введенного пользователем числа N, осуществляет вывод N кошек на экран. Пусть 1<= N <=10. Примечание: кошки при N=3 выглядят примерно так
# ```
#  /\__/\ /\__/\ /\__/\
#  /@ @\ /@ @\ /@ @\
#  (~~0~~) (~~0~~) (~~0~~)
# ```
# ________________________________________________________________________________________________________________
# def print_cats(N):
#     # Проверка допустимого диапазона N
#     if not 1 <= N <= 10:
#         print("Пожалуйста, введите число N в диапазоне от 1 до 10.")
#         return
#
#     # Отрисовка кошек
#     for _ in range(N):
#         print(" /\__/\ ", end=" ")
#     print()
#
#     for _ in range(N):
#         print(" /@ @\ ", end=" ")
#     print()
#
#     for _ in range(N):
#         print(" (~~0~~) ", end=" ")
#     print()
#
# # Ввод числа N от пользователя
# N = int(input("Введите число N (от 1 до 10): "))
#
# # Вывод кошек
# print_cats(N)
# ________________________________________________________________________________________________________________
# 16. Имеются два n – мерных вектора x и y, которые задают координаты n точек на плоскости (случайные целые числа). Найти наиболее близкие друг другу точки.
# 17. Из множества целых чисел от 1 до N выделить множество N2 числа, кратные 2, множество N3 – кратные 3, множество N 6 – кратные 6 (т.е. кратные и 2 и 3), множество N 23 – кратные либо 2, либо 3.
# ________________________________________________________________________________________________________________
# # Ввод числа N от пользователя
# N = int(input("Введите число N: "))
#
# # Создание множеств
# N2 = set()
# N3 = set()
# N6 = set()
# N23 = set()
#
# # Заполнение множеств
# for num in range(1, N + 1):
#     if num % 2 == 0:
#         N2.add(num)
#     if num % 3 == 0:
#         N3.add(num)
#     if num % 6 == 0:
#         N6.add(num)
#     if num % 2 == 0 or num % 3 == 0:
#         N23.add(num)
#
# # Вывод множеств
# print("Множество N2:", N2)
# print("Множество N3:", N3)
# print("Множество N6:", N6)
# print("Множество N23:", N23)
# ________________________________________________________________________________________________________________
# 18. Даны m (m>1) слов. Найти общее количество заданной буквы в этих словах.
# ________________________________________________________________________________________________________________
# # Ввод количества слов m
# m = int(input("Введите количество слов m: "))
#
# # Ввод буквы, которую нужно найти
# target_letter = input("Введите букву, которую нужно найти: ")
#
# # Инициализация счетчика
# total_count = 0
#
# # Ввод слов и поиск буквы
# for i in range(m):
#     word = input(f"Введите слово {i + 1}: ")
#     total_count += word.lower().count(target_letter.lower())
#
# # Вывод результата
# print(f"Общее количество букв '{target_letter}' в введенных словах: {total_count}")
# ________________________________________________________________________________________________________________
# 19. Даны m (m>1) слов. В каком из них доля (в %) заданной буквы больше.
# ________________________________________________________________________________________________________________
# # Ввод количества слов m
# m = int(input("Введите количество слов m: "))
#
# # Ввод буквы, долю которой нужно найти
# target_letter = input("Введите букву, долю которой нужно найти: ")
#
# # Инициализация переменных
# max_percentage = 0
# word_with_max_percentage = ""
#
# # Ввод слов и определение доли буквы в каждом слове
# for i in range(m):
#     word = input(f"Введите слово {i + 1}: ")
#
#     # Подсчет общего числа букв и числа заданной буквы в слове
#     total_letters = len(word)
#     target_letter_count = word.lower().count(target_letter.lower())
#
#     # Вычисление доли заданной буквы в слове
#     percentage = (target_letter_count / total_letters) * 100
#
#     # Обновление максимальной доли и слова с максимальной долей
#     if percentage > max_percentage:
#         max_percentage = percentage
#         word_with_max_percentage = word
#
# # Вывод результата
# print(f"Слово '{word_with_max_percentage}' имеет максимальную долю буквы '{target_letter}': {max_percentage:.2f}%")
# ________________________________________________________________________________________________________________
